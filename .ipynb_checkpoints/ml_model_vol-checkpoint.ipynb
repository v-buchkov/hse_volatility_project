# %%
import os

import numpy as np
import pandas as pd

# %%
BACKTEST_CCY = 'USDRUB'
BACKTEST_DAYS = 5

PATH_TEXTS = 'data/telegram'
PATH_OPT_PNL = 'data/pnl'

# %%
# Get all available data_sources
sources = os.listdir(PATH_TEXTS)
sources
# Out:
# ['cbonds.csv',
#  'themovchans.csv',
#  'headlines_QUANTS.csv',
#  'War_Wealth_Wisdom.csv',
#  'mmi.csv',
#  'vts.csv',
#  'signal.csv',
#  '.gitignore',
#  'rshb_invest.csv',
#  'Alfa_Wealth.csv',
#  'sky_bond.csv',
#  'bitkogan.csv']

# %%
# Generate dataframes
data_sources = []

for s in sources:
    if s != '.gitignore':
        source_data = pd.read_csv(f'{PATH_TEXTS}/{s}')
        data_sources.append((s.split('.')[0], source_data))

# %%
# Create target variable dataframe
pnl = pd.read_csv(f'{PATH_OPT_PNL}/Backtest_{BACKTEST_CCY}_{BACKTEST_DAYS}_days.txt')
pnl['date_start'] = pd.to_datetime(pnl['date_start']).dt.strftime('%Y-%m-%d')
pnl['pnl_sign'] = pnl['pnl'].apply(lambda x: 1 if x >= 0 else 0)
pnl
# Out:
#      date_start            pnl  pnl_sign
# 0    2021-01-04  291264.097914         1
# 1    2021-01-05 -411993.830320         0
# 2    2021-01-06  521491.686795         1
# 3    2021-01-08   62842.634116         1
# 4    2021-01-11 -537598.706217         0
# ..          ...            ...       ...
# 245  2021-12-20 -407527.554561         0
# 246  2021-12-21 -176881.417077         0
# 247  2021-12-22 -206943.414418         0
# 248  2021-12-23   23073.596468         1
# 249  2021-12-24  283960.438531         1
#
# [250 rows x 3 columns]

# %%
# Get balance of the sample
pnl['pnl_sign'].sum() / pnl.shape[0]
# Out:
# 0.536

# %%
# df = df[(df['date'] >= '2022-03-01') & (df['date'] <= '2022-10-31')]

# %%
data_sources[0][1]
# Out:
#           id                 date  \
# 0          9  2017-07-28T10:56:14
# 1         10  2017-08-03T15:28:17
# 2         11  2017-08-03T15:41:02
# 3         12  2017-08-03T18:11:32
# 4         13  2017-08-04T12:42:41
# ...      ...                  ...
# 11997  13124  2022-11-04T12:38:56
# 11998  13125  2022-11-04T13:17:23
# 11999  13126  2022-11-04T14:30:00
# 12000  13128  2022-11-05T11:30:11
# 12001  13129  2022-11-05T16:05:06
#
#                                                     text
# 0      Cbonds.ru  запустило канал в Telegram. Планиру...
# 1      Облигационный бюллетень Cbonds – все данные о ...
# 2      Cbonds prepared monthly report: CBONDS GLOBAL ...
# 3      Дайджест Cbonds от  3 августа:«Группа Компаний...
# 4      Совкомбанк открыл книгу заявок на вторичное ра...
# ...                                                  ...
# 11997  ​​ #РейтингиСНГ  🗂 Присвоение / Изменение рейт...
# 11998  #CbondsNewsletter 🌎📰  В октябре объем новых вы...
# 11999  ​​ 🏢Онлайн-семинар «Ключевые факты, финансовые...
# 12000  #Аналитика   🏆 Research Hub Cbonds: самое попу...
# 12001  #Интересное   🏦🔎Новый этап внедрения цифровых ...
#
# [12002 rows x 3 columns]

# %%
# df = pnl
# for source_name, source_dataframe in data_sources:
#     df[f'{source_name}'] = None
    
#     i = 0
#     texts = []
#     for _, row in source_dataframe.iterrows():
#         if i >= df.shape[0]:
#             break

#         if pd.to_datetime(row['date']).strftime('%Y-%m-%d') <= df['date_start'][i]:
#             texts.append(row['text'])
#         else:
#             df.at[i, source_name] = texts
#             texts = []
#             i += 1
#             continue

# %%
df = pnl
for source_name, source_dataframe in data_sources:
    df[f'{source_name}'] = ''
    
    i = 0
    texts = ''
    for _, row in source_dataframe.iterrows():
        if i >= df.shape[0]:
            break

        if pd.to_datetime(row['date']).strftime('%Y-%m-%d') <= df['date_start'][i]:
            texts += ' ' + row['text']
        else:
            df.at[i, source_name] = texts
            texts = ''
            i += 1
            continue

# %%
df = df.iloc[1:]
df
# Out:
#      date_start            pnl  pnl_sign  \
# 1    2021-01-05 -411993.830320         0
# 2    2021-01-06  521491.686795         1
# 3    2021-01-08   62842.634116         1
# 4    2021-01-11 -537598.706217         0
# 5    2021-01-12 -359059.057843         0
# ..          ...            ...       ...
# 245  2021-12-20 -407527.554561         0
# 246  2021-12-21 -176881.417077         0
# 247  2021-12-22 -206943.414418         0
# 248  2021-12-23   23073.596468         1
# 249  2021-12-24  283960.438531         1
#
#                                                 cbonds themovchans  \
# 1     ⚡️Российские компании: основные события, 5 ян...
# 2     ⚡️ Российские компании: основные события, 6 я...
# 3     🤔  Ключевая ставка ЦБ РФ останется на текущем...
# 4     ⚡️ Российские компании: основные события, 11 ...
# 5     🏛Неквалифицированным инвесторам не будут прод...
# ..                                                 ...         ...
# 245   #Интересное  🌱 📈ESG: Банки-дебютанты ЕС и рос...
# 246   ​​ 📝❓ Уже сегодня в 16:30 (мск): онлайн-семин...
# 247   #НовостиКомпаний  ⚡️Российские компании: осно...
# 248   ​​ 📝💡 Макроэкономические индикаторы по всем с...
# 249   #НовостиКомпаний  ⚡️Российские компании: осно...
#
#     headlines_QUANTS War_Wealth_Wisdom  \
# 1
# 2
# 3
# 4
# 5
# ..               ...               ...
# 245
# 246
# 247
# 248
# 249
#
#                                                    mmi vts  \
# 1     🔴🟢 - смешанные настроения на ЕМ, небольшой ро...
# 2     ВСЕМИРНЫЙ БАНК: \n•  РИСКИ НЕГАТИВНОГО РАЗВИТ...
# 3     🟢 - Risk-on на рынках продолжается. Беспорядк...
# 4     ГЛОБАЛЬНЫЙ РОСТ СТАВОК В НАЧАЛА ГОДА ПОКА НЕ ...
# 5     МАЛАЙЗИЯ ВВОДИТ ПОЛУГОДИЧНОЕ ЧРЕЗВЫЧАЙНОЕ ПОЛ...
# ..                                                 ...  ..
# 245   ЭКОНОМИКА – ПОСТКРИЗИСНЫЕ ТРЕНДЫ  Росстат на ...
# 246   УРОВЕНЬ ЗАБОЛЕВАЕМОСТИ В МИРЕ ВНОВЬ РАСТЕТ За...
# 247   РОСТ ПАНДЕМИИ В США УСИЛИВАЕТСЯ За последние ...
# 248   •   Рынок ОФЗ ведёт себя так, как будто увере...
# 249   ЧИСТЫЕ ЗВР ТУРЦИИ РУХНУЛИ ДО $12.2 МЛРД В чет...
#
#                                                 signal  \
# 1     🔦  Фокус недели   #ФН   Сегодня \n🛒 Акции Маг...
# 2     $=73,72р. RTS +0,68% BRENT +0,71%📌  LIVE Карт...
# 3     Уже даже Бэтмен около Капитолия #Макро   #Выб...
# 4     #Вирус   #Макро  \n⚡️ КОЛИЧЕСТВО ЗАРЕГИСТРИРО...
# 5     $=74,14р. RTS +0,90% BRENT +1,26%📌  LIVE Карт...
# ..                                                 ...
# 245   🔦 Фокус недели  #ФН  Сегодня\n🙋‍♂️ Самолет ( ...
# 246   🔦 Фокус недели  #ФН  Сегодня\n🤷‍♂️22 декабря\...
# 247   🔦 Фокус недели  #ФН  Сегодня\n💰 Детский мир (...
# 248   🔦 Фокус недели  #ФН  Сегодня\n❗️ Ежегодная пр...
# 249   🔦 Фокус недели  #ФН  Сегодня\n💰 Газпром нефть...
#
#                                            rshb_invest Alfa_Wealth sky_bond  \
# 1
# 2
# 3
# 4     🇺🇸 В моменте доходность по десятилетней треже...
# 5     ГЛАВНОЕ В РОССИИ США обвинили Россию в попытк...
# ..                                                 ...         ...      ...
# 245   ГЛАВНОЕ В РОССИИ \n \n📈 Ключевая ставка увели...
# 246   ГЛАВНОЕ В РОССИИ 📊 "Ренессанс страхование" ра...
# 247   ГЛАВНОЕ В РОССИИ 📊 Reuters: в 2022 году «Атон...
# 248   ГЛАВНОЕ В РОССИИ 📊 Инфляция в России с 14 по ...
# 249   ГЛАВНОЕ В РОССИИ 📊 Белоусов: Роснано будет ок...
#
#                                               bitkogan
# 1     Brent Light По итогам первого торгового дня г...
# 2     Нефть марки Brent. «Коммунисты России» жгут. ...
# 3     Друзья!\nНаш хрупкий мир держится на целой си...
# 4     Во время протестов  задержана женщина  молдав...
# 5     Кстати, про рубль. \n \n Вопреки всем обещани...
# ..                                                 ...
# 245   4️⃣  Укрепление положения на рынке . Некоторы...
# 246   Micron помогает обыгрывать рынки Вчера, когда...
# 247   China Mobile в Шанхае – второй после Rivian к...
# 248   Уже не такой страшный Омикрон напугал Сиань ....
# 249   Индекс NASDAQ. Доброе утро, друзья! Перед Рож...
#
# [249 rows x 14 columns]

# %%
df = df[~df.isin([''])].dropna(axis=1, how='all')

# %%
df_final = df.drop(['cbonds', 'signal', 'rshb_invest', 'Alfa_Wealth'], axis=1, inplace=True)
df_final = df
df_final
# Out:
#      date_start            pnl  pnl_sign  \
# 1    2021-01-05 -411993.830320         0
# 2    2021-01-06  521491.686795         1
# 3    2021-01-08   62842.634116         1
# 4    2021-01-11 -537598.706217         0
# 5    2021-01-12 -359059.057843         0
# ..          ...            ...       ...
# 245  2021-12-20 -407527.554561         0
# 246  2021-12-21 -176881.417077         0
# 247  2021-12-22 -206943.414418         0
# 248  2021-12-23   23073.596468         1
# 249  2021-12-24  283960.438531         1
#
#                                                    mmi  \
# 1     🔴🟢 - смешанные настроения на ЕМ, небольшой ро...
# 2     ВСЕМИРНЫЙ БАНК: \n•  РИСКИ НЕГАТИВНОГО РАЗВИТ...
# 3     🟢 - Risk-on на рынках продолжается. Беспорядк...
# 4     ГЛОБАЛЬНЫЙ РОСТ СТАВОК В НАЧАЛА ГОДА ПОКА НЕ ...
# 5     МАЛАЙЗИЯ ВВОДИТ ПОЛУГОДИЧНОЕ ЧРЕЗВЫЧАЙНОЕ ПОЛ...
# ..                                                 ...
# 245   ЭКОНОМИКА – ПОСТКРИЗИСНЫЕ ТРЕНДЫ  Росстат на ...
# 246   УРОВЕНЬ ЗАБОЛЕВАЕМОСТИ В МИРЕ ВНОВЬ РАСТЕТ За...
# 247   РОСТ ПАНДЕМИИ В США УСИЛИВАЕТСЯ За последние ...
# 248   •   Рынок ОФЗ ведёт себя так, как будто увере...
# 249   ЧИСТЫЕ ЗВР ТУРЦИИ РУХНУЛИ ДО $12.2 МЛРД В чет...
#
#                                               bitkogan
# 1     Brent Light По итогам первого торгового дня г...
# 2     Нефть марки Brent. «Коммунисты России» жгут. ...
# 3     Друзья!\nНаш хрупкий мир держится на целой си...
# 4     Во время протестов  задержана женщина  молдав...
# 5     Кстати, про рубль. \n \n Вопреки всем обещани...
# ..                                                 ...
# 245   4️⃣  Укрепление положения на рынке . Некоторы...
# 246   Micron помогает обыгрывать рынки Вчера, когда...
# 247   China Mobile в Шанхае – второй после Rivian к...
# 248   Уже не такой страшный Омикрон напугал Сиань ....
# 249   Индекс NASDAQ. Доброе утро, друзья! Перед Рож...
#
# [249 rows x 5 columns]

# %%
X = df_final.drop(['date_start', 'pnl', 'pnl_sign'], axis=1)
y = df_final['pnl_sign']

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=121)

# %%
X_train.shape
# Out:
# (199, 2)

# %%
import nltk
nltk.download("stopwords")

from nltk.corpus import stopwords

russian_stopwords = stopwords.words("russian")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/buchkovv/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# from scipy.sparse import coo_matrix, hstack
# from sklearn.feature_extraction.text import TfidfVectorizer

# X_train_transformed = []
# X_val_transformed = []
# for i in range(len(X_train.columns)):
#     tf_idf = TfidfVectorizer(stop_words=russian_stopwords, ngram_range=(1,1))
    
#     X_train_transformed.append(coo_matrix(tf_idf.fit_transform(X_train.iloc[:,i].astype(str))))
#     X_val_transformed.append(coo_matrix(tf_idf.transform(X_val.iloc[:,i].astype(str))))

# %%
class Word2VecTransformer:
    
    def __init__(self, w2v_model, word_pattern):
        
        self.w2v_model = w2v_model
        self.word_pattern = word_pattern
        self.re = re.compile(pattern=self.word_pattern)
        
    def fit(self, X):
        return self
    
    def transform(self, X):
        
        X_transformed = np.zeros((len(X), self.w2v_model.wv.vector_size))
        for i, title in enumerate(X):
            
            title_vector = np.zeros((self.w2v_model.wv.vector_size,))
            tokens = self.re.findall(title.lower())
            for token in tokens:
                if token in self.w2v_model.wv.key_to_index:
                    title_vector += self.w2v_model.wv.get_vector(token)
                    
            X_transformed[i] = title_vector
        
        return X_transformed

# %%
import re
from gensim.models.word2vec import Word2Vec
from sklearn.linear_model import SGDClassifier

# From CountVectorizer() (default pattern)
WORD_PATTERN = '(?u)\\b\\w\\w+\\b'

reg_exp = re.compile(pattern=WORD_PATTERN)

X_train_transformed = np.empty(shape=(len(y_train), 100))
X_val_transformed = np.empty(shape=(len(y_val), 100))
for i in range(len(X_train.columns)):
    sentences = [reg_exp.findall(s.lower()) for s in X_train.iloc[:,i].astype(str)]
    w2v_model = Word2Vec(sg=1,)
    w2v_model.build_vocab(sentences)
    w2v_model.train(
        sentences,
        total_examples=w2v_model.corpus_count,
        epochs=20,
        compute_loss=True
    )
    
    w2v_transformer = Word2VecTransformer(w2v_model=w2v_model, word_pattern=WORD_PATTERN)

    train_w2v = w2v_transformer.transform(X_train.iloc[:,i].astype(str))
    val_w2v = w2v_transformer.transform(X_val.iloc[:,i].astype(str))
    
    print(X_train_transformed)
    
    X_train_transformed = np.append(X_train_transformed, train_w2v, axis=1)
    X_val_transformed = np.append(X_val_transformed, val_w2v, axis=1)

X_train_transformed.shape
# Out:
# Index(['mmi', 'bitkogan'], dtype='object')
# [[2.30236543e-311 2.28114548e-311 6.79038658e-313 ... 2.28326747e-311
#   2.31297541e-311 2.27477949e-311]
#  [9.76118069e-313 2.22385159e-311 2.22809558e-311 ... 2.30024344e-311
#   6.79038659e-313 2.27477949e-311]
#  [6.79038658e-313 2.30236543e-311 2.31297541e-311 ... 2.29175545e-311
#   2.27902348e-311 2.28751146e-311]
#  ...
#  [2.28538947e-311 2.31297541e-311 2.30873142e-311 ... 2.32358539e-311
#   2.30448743e-311 2.30873142e-311]
#  [2.31085342e-311 2.29175545e-311 2.31085342e-311 ... 2.27902348e-311
#   2.30873142e-311 2.33207337e-311]
#  [6.79038658e-313 2.30448743e-311 2.30448743e-311 ... 2.34056136e-311
#   6.79038659e-313 2.30873142e-311]]
# [[ 2.30236543e-311  2.28114548e-311  6.79038658e-313 ... -2.68015921e+002
#   -2.10060472e+001 -1.59057619e+002]
#  [ 9.76118069e-313  2.22385159e-311  2.22809558e-311 ... -3.40309472e+002
#    1.57101133e+001 -1.46895825e+002]
#  [ 6.79038658e-313  2.30236543e-311  2.31297541e-311 ... -1.39817182e+002
#    2.37794523e+001 -4.70141493e+001]
#  ...
#  [ 2.28538947e-311  2.31297541e-311  2.30873142e-311 ... -3.72219003e+002
#    5.52977798e+001 -1.22404170e+002]
#  [ 2.31085342e-311  2.29175545e-311  2.31085342e-311 ... -2.95084673e+002
#   -5.04341452e+001 -1.67648703e+002]
#  [ 6.79038658e-313  2.30448743e-311  2.30448743e-311 ... -3.43035774e+002
#   -5.21986562e+000 -1.32866459e+002]]
# (199, 300)

# %%
# X_train_transformed = np.vstack(X_train_transformed)
# X_val_transformed = np.vstack(X_val_transformed)
# X_train_transformed.shape
# Out:
# (1, 119400)

# %%
y_train.shape
# Out:
# (199,)

# %%
# for x in X_train_transformed:
#     print(x.shape)
# Out:
# (199, 100)
# (199, 100)
# (199, 100)
# (199, 100)
# (199, 100)
# (199, 100)

# %%
# X_train_transformed = hstack(X_train_transformed)
# X_val_transformed = hstack(X_val_transformed)
# X_train_transformed
# Out:
# <199x600 sparse matrix of type '<class 'numpy.float64'>'
# 	with 119400 stored elements in COOrdinate format>

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(multi_class='auto', solver='lbfgs', verbose=False)
log_reg.fit(X_train_transformed, y_train)

preds = log_reg.predict(X_val_transformed)
accuracy_score(preds, y_val)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [98], in <cell line: 5>()
#       2 from sklearn.linear_model import LogisticRegression
#       4 log_reg = LogisticRegression(multi_class='auto', solver='lbfgs', verbose=False)
# ----> 5 log_reg.fit(X_train_transformed, y_train)
#       7 preds = log_reg.predict(X_val_transformed)
#       8 accuracy_score(preds, y_val)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1138, in LogisticRegression.fit(self, X, y, sample_weight)
#    1135 else:
#    1136     _dtype = [np.float64, np.float32]
# -> 1138 X, y = self._validate_data(
#    1139     X,
#    1140     y,
#    1141     accept_sparse="csr",
#    1142     dtype=_dtype,
#    1143     order="C",
#    1144     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1145 )
#    1146 check_classification_targets(y)
#    1147 self.classes_ = np.unique(y)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:596, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     594         y = check_array(y, input_name="y", **check_y_params)
#     595     else:
# --> 596         X, y = check_X_y(X, y, **check_params)
#     597     out = X, y
#     599 if not no_val_X and check_params.get("ensure_2d", True):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/validation.py:1074, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1069         estimator_name = _check_estimator_name(estimator)
#    1070     raise ValueError(
#    1071         f"{estimator_name} requires y to be passed, but the target y is None"
#    1072     )
# -> 1074 X = check_array(
#    1075     X,
#    1076     accept_sparse=accept_sparse,
#    1077     accept_large_sparse=accept_large_sparse,
#    1078     dtype=dtype,
#    1079     order=order,
#    1080     copy=copy,
#    1081     force_all_finite=force_all_finite,
#    1082     ensure_2d=ensure_2d,
#    1083     allow_nd=allow_nd,
#    1084     ensure_min_samples=ensure_min_samples,
#    1085     ensure_min_features=ensure_min_features,
#    1086     estimator=estimator,
#    1087     input_name="X",
#    1088 )
#    1090 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1092 check_consistent_length(X, y)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/validation.py:899, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     893         raise ValueError(
#     894             "Found array with dim %d. %s expected <= 2."
#     895             % (array.ndim, estimator_name)
#     896         )
#     898     if force_all_finite:
# --> 899         _assert_all_finite(
#     900             array,
#     901             input_name=input_name,
#     902             estimator_name=estimator_name,
#     903             allow_nan=force_all_finite == "allow-nan",
#     904         )
#     906 if ensure_min_samples > 0:
#     907     n_samples = _num_samples(array)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/validation.py:146, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     124         if (
#     125             not allow_nan
#     126             and estimator_name
#    (...)
#     130             # Improve the error message on how to handle missing values in
#     131             # scikit-learn.
#     132             msg_err += (
#     133                 f"\n{estimator_name} does not accept missing values"
#     134                 " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     144                 "#estimators-that-handle-nan-values"
#     145             )
# --> 146         raise ValueError(msg_err)
#     148 # for object dtype data, we only check for NaNs (GH-13254)
#     149 elif X.dtype == np.dtype("object") and not allow_nan:
#
# ValueError: Input X contains NaN.
# LogisticRegression does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
